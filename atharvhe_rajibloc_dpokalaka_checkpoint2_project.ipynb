# %%
import pandas as pd
import numpy as np
import json
import os
from pprint import pprint
import bitsandbytes as bnb
import torch
import torch.nn as nn
import transformers
from datasets import load_dataset, Dataset
import wandb
from huggingface_hub import notebook_login

from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig, PeftConfig, PeftModel, get_peft_model, prepare_model_for_kbit_training

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
MODEL_NAME = "deepseek-ai/deepseek-math-7b-rl"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    trust_remote_code=True,
    quantization_config=bnb_config
)

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
model = prepare_model_for_kbit_training(model)

# %%
import re
def get_num_layers(model):
    numbers = set()
    for name, _ in model.named_parameters():
        for number in re.findall(r'\d+', name):
            numbers.add(int(number))
    return max(numbers)

def get_last_layer_linears(model):
    names = []
    
    num_layers = get_num_layers(model)
    for name, module in model.named_modules():
        if str(num_layers) in name and not "encoder" in name:
            if isinstance(module, torch.nn.Linear):
                names.append(name)
    return names
def clean_output(txt):
    try:
        txt = txt[-30:]
        pattern = r"(\d+)$"
        ans_cln = re.sub(r"\D", " ", txt).strip()
        matches = re.findall(pattern, ans_cln)
        return int(matches[0])
    except:
        return np.NaN

# %%
config = LoraConfig(
    r=20,
    lora_alpha=45,
    target_modules=get_last_layer_linears(model),
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)

# %%
df1 = pd.read_csv("Data/combined_dataset.csv")
df2 = pd.read_csv("Data/AIMO/data.csv")

# %%
def clean_output(txt):
    try:
        txt = txt[-30:]
        pattern = r"(\d+)$"
        ans_cln = re.sub(r"\D", " ", txt).strip()
        matches = re.findall(pattern, ans_cln)
        return int(matches[0])
    except:
        return np.NaN

# %%
ans = []
for i, sol in df1[df1['answers'].isna()][['solutions']].iterrows():
    df1.loc[i, 'answers'] = clean_output(sol['solutions'])

# %%
df1 = df1.rename(columns={"questions":"problem", "answers":"answer", "solutions":"solution"})

# %%
def clean_sol(text):
    return re.sub(r'[\-~][^\s]*$', '', text).strip()
df1['solution'] = df1['solution'].fillna("").apply(clean_sol).values

# %%
df1 = df1[~df1['problem'].isna()].copy()

# %%
df = df1.copy()

# %%
def is_integer(text):
    try:
        if int(text) >= 0:
            return True
        else:
            return False
    except ValueError:
        return False
    
df["is_integer"] = df.answer.map(is_integer)
df = df[df.is_integer].reset_index(drop=True)
df.head(2)
# Out:
#                                              problem  \
# 0  Every morning Aya goes for a $9$ -kilometer-lo...
# 1  Alice and Bob play the following game. A stack...
#
#                                             solution answer  is_integer
# 0  $\frac{9}{s} + t = 4$ in hours and $\frac{9}{s...    204        True
# 1  Let's first try some experimentation. Alice ob...    809        True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8300 entries, 0 to 8299
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   problem     8300 non-null   object
#  1   solution    8300 non-null   object
#  2   answer      8300 non-null   object
#  3   is_integer  8300 non-null   bool
# dtypes: bool(1), object(3)
# memory usage: 202.8+ KB

# %%
df['answer'] = df['answer'].astype('int')

# %%
data = Dataset.from_pandas(df[['problem', 'solution', 'answer']].sample(100))

# %%
data
# Out:
# Dataset({
#     features: ['problem', 'solution', 'answer', '__index_level_0__'],
#     num_rows: 100
# })

# %%
template = """Role:\nYou are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.\n\nInstruction:
1. Carefully read and comprehend the problem statement provided in the "Problem" section.
2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative."""

# %%
prompt = template + "\n\nProblem: " + df["problem"].values[0] + " ".strip()
print(prompt)
# Out:
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: Every morning Aya goes for a $9$ -kilometer-long walk and stops at a coffee shop afterwards. When she walks at a constant speed of $s$ kilometers per hour, the walk takes her 4 hours, including $t$ minutes spent in the coffee shop. When she walks $s+2$ kilometers per hour, the walk takes her 2 hours and 24 minutes, including $t$ minutes spent in the coffee shop. Suppose Aya walks at $s+\frac{1}{2}$ kilometers per hour. Find the number of minutes the walk takes her, including the $t$ minutes spent in the coffee shop.

# %%
generation_config = model.generation_config
generation_config.max_new_tokens = 10000
generation_config.temperature = 0.8
generation_config.do_sample = True
generation_config.return_full_text=False
# generation_config.num_return_sequences = 1
generation_config.pad_token_id = tokenizer.eos_token_id
generation_config.eos_token_id = tokenizer.eos_token_id

# %%
# %%time
device = "cuda"

encoding = tokenizer(prompt, return_tensors="pt").to(device)
with torch.no_grad():
    outputs = model.generate(
        input_ids = encoding.input_ids,
        attention_mask = encoding.attention_mask,
        generation_config = generation_config
    )

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: Every morning Aya goes for a $9$ -kilometer-long walk and stops at a coffee shop afterwards. When she walks at a constant speed of $s$ kilometers per hour, the walk takes her 4 hours, including $t$ minutes spent in the coffee shop. When she walks $s+2$ kilometers per hour, the walk takes her 2 hours and 24 minutes, including $t$ minutes spent in the coffee shop. Suppose Aya walks at $s+\frac{1}{2}$ kilometers per hour. Find the number of minutes the walk takes her, including the $t$ minutes spent in the coffee shop.
#
# Solution: Let's break down the problem into smaller steps.
#
# Step 1: Convert the time in minutes for the given times.
# The walk takes 4 hours, including $t$ minutes spent in the coffee shop. Since 1 hour is equal to 60 minutes, the walk takes 4*60 = 240 minutes. Adding the $t$ minutes in the coffee shop, the total time is $240+t$ minutes.
# Similarly, the walk takes 2 hours and 24 minutes, including $t$ minutes spent in the coffee shop. This is equal to 2*60 + 24 = 144 minutes. Adding the $t$ minutes in the coffee shop, the total time is $144+t$ minutes.
#
# Step 2: Set up the equations based on the total distances and speeds.
# The distance of the walk is 9 kilometers. When she walks at a constant speed of $s$ kilometers per hour, the walk takes her 240 minutes. This gives us the equation $9 = s*\frac{240}{60}$, or $9 = 4s$.
# When she walks $s+2$ kilometers per hour, the walk takes her 144 minutes. This gives us the equation $9 = (s+2)*\frac{144}{60}$, or $9 = 2.4(s+2)$.
#
# Step 3: Solve the equations to find the value of $s$.
# From the equation $9 = 4s$, we can solve for $s$ to get $s = \frac{9}{4} = 2.25$.
# Substituting $s = 2.25$ into the equation $9 = 2.4(s+2)$, we get $9 = 2.4(2.25+2) = 2.4*4.25 = 10.2$. This is not true, so we must have made a mistake in our calculations.
#
# Let's go back and re-evaluate our steps.
#
# Step 1: Convert the time in minutes for the given times.
# The walk takes 4 hours, including $t$ minutes spent in the coffee shop. Since 1 hour is equal to 60 minutes, the walk takes 4*60 = 240 minutes. Adding the $t$ minutes in the coffee shop, the total time is $240+t$ minutes.
# Similarly, the walk takes 2 hours and 24 minutes, including $t$ minutes spent in the coffee shop. This is equal to 2*60 + 24 = 144 minutes. Adding the $t$ minutes in the coffee shop, the total time is $144+t$ minutes.
#
# Step 2: Set up the equations based on the total distances and speeds.
# The distance of the walk is 9 kilometers. When she walks at a constant speed of $s$ kilometers per hour, the walk takes her 240 minutes. This gives us the equation $9 = s*\frac{240}{60}$, or $9 = 4s$. This is correct.
# When she walks $s+2$ kilometers per hour, the walk takes her 144 minutes. This gives us the equation $9 = (s+2)*\frac{144}{60}$, or $9 = 2.4(s+2)$. This is also correct.
#
# Step 3: Solve the equations to find the value of $s$.
# From the equation $9 = 4s$, we can solve for $s$ to get $s = \frac{9}{4} = 2.25$. This is correct.
# Substituting $s = 2.25$ into the equation $9 = 2.4(s+2)$, we get $9 = 2.4(2.25+2) = 2.4*4.25 = 10.2$. This is true, so our calculations are correct.
#
# Step 4: Find the value of $s+\frac{1}{2}$.
# Substituting $s = 2.25$ into $s+\frac{1}{2}$, we get $2.25+\frac{1}{2} = 2.25+0.5 = 2.75$.
#
# Step 5: Find the time it takes for the walk at $s+\frac{1}{2}$ kilometers per hour.
# The time it takes for the walk at $s+\frac{1}{2}$ kilometers per hour is $\frac{9}{2.75} = \frac{9*2}{5.5*2} = \frac{18}{11}$ hours. Converting this to minutes, we get $\frac{18}{11}*60 = \frac{1080}{11} \approx 98.18$ minutes.
#
# Step 6: Find the number of minutes the walk takes her, including the $t$ minutes spent in the coffee shop.
# Since we know that the walk takes approximately 98.18 minutes and including the $t$ minutes spent in the coffee shop, the total time is $98.18+t$ minutes.
# However, we are not given the value of $t$, so we cannot determine the exact value of $98.18+t$.
#
# In conclusion, based on the given information, we cannot determine the exact number of minutes the walk takes her, including the $t$ minutes spent in the coffee shop.
# The value of $s$ is 2.25, and the value of $s+\frac{1}{2}$ is 2.75.
# CPU times: user 2min 17s, sys: 361 ms, total: 2min 18s
# Wall time: 2min 18s

# %%
def generate_prompt(data_point, template):
    prompt = template + "\n\nProblem: " + df["problem"].values[0] + " ".strip()
    return prompt


def generate_and_tokenize_prompt(data_point):
    full_prompt = generate_prompt(data_point, template)
    tokenized_full_prompt = tokenizer(full_prompt, padding=True, truncation=True)
    return tokenized_full_prompt

data = data.shuffle().map(generate_and_tokenize_prompt)
# Out:
#   0%|          | 0/100 [00:00<?, ?ex/s]

# %%
data
# Out:
# Dataset({
#     features: ['problem', 'solution', 'answer', '__index_level_0__', 'input_ids', 'attention_mask'],
#     num_rows: 100
# })

# %%
print(data['problem'][0])
# Out:
# The greatest common divisor of two positive integers is $(x+5)$ and their least common multiple is $x(x+5)$, where $x$ is a positive integer. If one of the integers is 50, what is the smallest possible value of the other one?

# %%
training_args = transformers.TrainingArguments(
    per_device_train_batch_size=1,
    gradient_accumulation_steps=4,
    num_train_epochs=1,
    learning_rate=1e-4,
    fp16=True,
    output_dir="checkpoints",
    optim="paged_adamw_8bit",
    lr_scheduler_type="cosine",
    warmup_ratio=0.01,
    logging_steps=5
)

trainer = transformers.Trainer(
    model=model,
    train_dataset=data,
    args=training_args,
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = False
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.17.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240707_034516-3s9uvtsb</code>
# Syncing run <strong><a href='https://wandb.ai/rldhub/huggingface/runs/3s9uvtsb' target="_blank">dashing-dragon-14</a></strong> to <a href='https://wandb.ai/rldhub/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rldhub/huggingface' target="_blank">https://wandb.ai/rldhub/huggingface</a>
#  View run at <a href='https://wandb.ai/rldhub/huggingface/runs/3s9uvtsb' target="_blank">https://wandb.ai/rldhub/huggingface/runs/3s9uvtsb</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 03:12, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.210800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.152600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.070100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.003400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.977100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=25, training_loss=2.082794494628906, metrics={'train_runtime': 419.0878, 'train_samples_per_second': 0.239, 'train_steps_per_second': 0.06, 'total_flos': 653348312064000.0, 'train_loss': 2.082794494628906, 'epoch': 1.0})

# %%
model.save_pretrained("Model/deepseekmath")
# Out:
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:195: UserWarning: Could not find a config file in /kaggle/input/deepseek-math - will assume that the vocabulary was not modified.
#   warnings.warn(

# %%
PEFT_MODEL = "Model/deepseekmath"

config = PeftConfig.from_pretrained(PEFT_MODEL)
model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    return_dict=True,
    quantization_config=bnb_config,
    device_map="sequential",
    trust_remote_code=True
)

tokenizer=AutoTokenizer.from_pretrained(config.base_model_name_or_path)
tokenizer.pad_token = tokenizer.eos_token

model = PeftModel.from_pretrained(model, PEFT_MODEL)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
generation_config = model.generation_config
generation_config.max_new_tokens = 10000
generation_config.temperature = 0.8
generation_config.do_sample = True
generation_config.return_full_text=False
# generation_config.num_return_sequences = 1
generation_config.pad_token_id = tokenizer.eos_token_id
generation_config.eos_token_id = tokenizer.eos_token_id

# %%
import numpy as np

# %%
res = []
for i in range(len(df2)):
    prompt = template + "\n\nProblem: " + df2["problem"].values[i] + " ".strip() 

    device = "cuda"
    encoding = tokenizer(prompt, return_tensors="pt").to(device)
    with torch.inference_mode():
        outputs = model.generate(
          input_ids = encoding.input_ids,
          attention_mask = encoding.attention_mask,
          generation_config = generation_config
      )
    output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(output)
    res.append(clean_output(output))
# Out:
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: Let $k, l > 0$ be parameters. The parabola $y = kx^2 - 2kx + l$ intersects the line $y = 4$ at two points $A$ and $B$. These points are distance 6 apart. What is the sum of the squares of the distances from $A$ and $B$ to the origin?
#
# Solution: The parabola $y = kx^2 - 2kx + l$ intersects the line $y = 4$ at two points, so we set $kx^2 - 2kx + l = 4$. This simplifies to $kx^2 - 2kx + l - 4 = 0$. Let the $x$-coordinates of points $A$ and $B$ be $x_1$ and $x_2$, respectively. Then by the quadratic formula, we have $x_{1,2} = \frac{2k \pm \sqrt{(2k)^2 - 4k(l - 4)}}{2k} = 1 \pm \frac{\sqrt{4k - 4kl + 16k}}{2k}$.
#
# The distance between $A$ and $B$ is 6, so $|x_2 - x_1| = 6$. We have
# \begin{align*}
# 6 &= \left| \left(1 + \frac{\sqrt{4k - 4kl + 16k}}{2k}\right) - \left(1 - \frac{\sqrt{4k - 4kl + 16k}}{2k}\right) \right| \\
# &= \frac{\sqrt{4k - 4kl + 16k}}{k}.
# \end{align*}
# Simplifying, we get $36k^2 = 4k - 4kl + 16k$, or $36k^2 = 20k - 4kl$. Rearranging terms, we have $4kl = 20k - 36k^2 = 4k(5 - 9k)$. Since $k, l > 0$, we can divide both sides by $4k$ to get $l = 5 - 9k$.
#
# The distance from a point $(x, y)$ to the origin is $\sqrt{x^2 + y^2}$. The distance from $A$ to the origin is $\sqrt{x_1^2 + (k x_1^2 - 2k x_1 + l)^2}$, and similarly for $B$. We want to find $d_A^2 + d_B^2$, where $d_A$ and $d_B$ are the distances from $A$ and $B$ to the origin, respectively.
#
# Using the values of $x_1$ and $x_2$, we have
# \begin{align*}
# d_A^2 + d_B^2 &= \left(x_1^2 + (k x_1^2 - 2k x_1 + l)^2\right) + \left(x_2^2 + (k x_2^2 - 2k x_2 + l)^2\right) \\
# &= \left(1 + \left(k - 2k + 5 - 9k\right)^2\right) + \left(9 + \left(9k - 18k + 5 - 9k\right)^2\right) \\
# &= \left(1 + (5 - 10k)^2\right) + \left(9 + (5 - 9k)^2\right) \\
# &= 1 + 25 - 100k + 100k^2 + 81 + 25 - 90k + 81k^2 \\
# &= 106 + 181k^2 - 110k.
# \end{align*}
# To find the value of this expression, we need to find the values of $k$ and $l$. From $l = 5 - 9k$, we can substitute $l$ into the equation $36k^2 = 20k - 4kl$ to get
# \[36k^2 = 20k - 4k(5 - 9k),\]
# which simplifies to $36k^2 = 20k - 20k + 36k^2$, or $0 = 0$. This means that our value of $l$ is correct, and we can substitute $l = 5 - 9k$ into $d_A^2 + d_B^2 = 106 + 181k^2 - 110k$ to get
# \[d_A^2 + d_B^2 = 106 + 181k^2 - 110k.\]
# To find the value of this expression for a specific value of $k$, we can substitute that value into the expression and calculate the result. However, this problem does not provide enough information to uniquely determine the value of $k$, so we cannot find the exact value of $d_A^2 + d_B^2$. Nevertheless, the expression $106 + 181k^2 - 110k$ gives a general formula for the sum of the squares of the distances from $A$ and $B$ to the origin in terms of $k$.
# The answer is: $106 + 181k^2 - 110k$.
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: Each of the three-digits numbers $111$ to $999$ is coloured blue or yellow in such a way that the sum of any two (not necessarily different) yellow numbers is equal to a blue number. What is the maximum possible number of yellow numbers there can be?
#
# Solution: Let's denote the number of yellow numbers as $y$ and the number of blue numbers as $b$. Since each of the three-digit numbers from 111 to 999 is colored either blue or yellow, we have $y + b = 999 - 111 + 1 = 899$.
#
# Now, let's consider the minimum number of blue numbers. The smallest possible blue number is 111 and the largest possible yellow number is 999. If we choose the blue number as 111, then for any yellow number $y$, the sum $y + 111$ must be a blue number. The largest possible yellow number is 999, so the smallest possible blue number when $y = 999$ is $999 + 111 - 999 = 111$. This means that all the numbers from 111 to 999 are blue, so there are no yellow numbers, which is a contradiction because we are asked to find the maximum number of yellow numbers.
#
# Hence, we need to find the maximum number of yellow numbers while still having at least one blue number. The key observation is that for any two yellow numbers $y_1$ and $y_2$, the sum $y_1 + y_2$ must be a blue number. This means that the sum of any pair of yellow numbers must have the form $111 + k$, where $k$ is a non-negative integer.
#
# Let's start by setting $y_1 = 111$. Then, for any yellow number $y_2$, the sum $y_1 + y_2 = 111 + y_2$ must be a blue number. The largest possible value of $y_2$ is 999, so $111 + y_2 = 999$, which gives $y_2 = 888$. Therefore, we have found one yellow number, $111$, and one blue number, $999$.
#
# Now, let's consider adding another yellow number $y_3$. The sum $y_1 + y_3 = 111 + y_3$ must be a blue number, which means $111 + y_3 = 999 + k$ for some non-negative integer $k$. Simplifying this equation gives $y_3 = 888 + k$. Since $y_3$ must be a yellow number, it must be less than or equal to 999. The largest possible value of $k$ is when $y_3 = 999$, so $999 = 888 + k$, which gives $k = 111$. Therefore, we can add another yellow number $y_3 = 999 - 111 = 888$.
#
# Adding another yellow number $y_4$ would result in a sum $y_1 + y_4 = 111 + y_4$ that is larger than 999, so we cannot add any more yellow numbers without violating the conditions of the problem.
#
# Therefore, the maximum number of yellow numbers is 2, with the yellow numbers being 111 and 888. The number of blue numbers is 897 (since $y + b = 899$ and $y = 2$).
#
# The maximum number of yellow numbers is 2.
# The answer is: 2
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: Let the `sparkle' operation on positive integer $n$ consist of calculating the sum of the digits of $n$ and taking its factorial, e.g. the sparkle of 13 is $4! = 24$. A robot starts with a positive integer on a blackboard, then after each second for the rest of eternity, replaces the number on the board with its sparkle. For some `special' numbers, if they're the first number, then eventually every number that appears will be less than 6. How many such special numbers are there with at most 36 digits?
#
# Solution: First, let's consider the numbers less than 6. The only possible numbers are 1, 2, 3, 4, and 5. If the number is 1, 2, 3, 4, or 5, after one application of the `sparkle' operation, we get 1, 2, 6, 24, or 120 respectively. All of these are less than 6.
#
# Now, let's consider a number greater than 5 but less than 6. If the number is 6, after one application of the `sparkle' operation, we get $6! = 720$. Since 720 is greater than 5, we need to check the sparkle of 720. The sparkle of 720 is $7+2+0 = 9$, and $9! = 362880$. This is too large to be considered.
#
# Therefore, the only special numbers with at most 36 digits are those less than or equal to 5. There are 5 such numbers.
# The answer is $\boxed{5}$.
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: What is the minimum value of $5x^2+5y^2-8xy$ when $x$ and $y$ range over all real numbers such that $|x-2y| + |y-2x| = 40$?
#
# Solution: We can observe that $|x-2y| + |y-2x| = 40$ can be rewritten as $|x-2y| = |y-2x|$. This implies that $x-2y = y-2x$ or $x-2y = -(y-2x)$.
# Solving the first equation $x-2y = y-2x$, we get $3x = 3y$, so $x=y$.
# Substituting this into the second equation $x-2y = -(y-2x)$, we get $x-2x = -y+2y$, which simplifies to $-x = y$.
# So, $x=y=-x$, which implies $x=y=0$.
# Now, we substitute $x=y=0$ into the expression $5x^2+5y^2-8xy$ to get $5(0)^2+5(0)^2-8(0)(0) = 0$.
# Therefore, the minimum value of $5x^2+5y^2-8xy$ is 0.
# The answer is: $0$
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: There exists a unique increasing geometric sequence of five 2-digit positive integers. What is their sum?
#
# Solution: Let the five terms of the geometric sequence be $a,$ $ar,$ $ar^2,$ $ar^3,$ $ar^4,$ where $a$ is the first term and $r$ is the common ratio. Since we are looking for 2-digit positive integers, $a$ must be a 2-digit positive integer and $r$ must be a positive integer because the sequence is increasing.
#
# Since the sequence is increasing, $r > 1$. To find the minimum value of $a$, we want $r$ to be as small as possible. The smallest integer $r$ can be is $2$, because if we choose $r = 1$, the sequence would be just five identical 2-digit numbers, which is not what we want.
#
# So, the minimum value of $a$ is the smallest 2-digit number, which is $10$. With $a = 10$ and $r = 2$, the sequence becomes $10,$ $20,$ $40,$ $80,$ $160$. However, $160$ is not a 2-digit number, so we need to increase $a$.
#
# If we try $a = 11,$ the sequence becomes $11,$ $22,$ $44,$ $88,$ $176,$ and $176$ is still not a 2-digit number. We can keep increasing $a$ until we find a value that works. When we try $a = 12$, the sequence becomes $12,$ $24,$ $48,$ $96,$ $192,$ and $192$ is a 2-digit number. So, the sequence is $12,$ $24,$ $48,$ $96,$ $192$. This sequence satisfies all the conditions: it is an increasing geometric sequence of five 2-digit positive integers.
#
# To find the sum of the sequence, we simply add up the five terms: $12 + 24 + 48 + 96 + 192 = 372$. So, the sum of the sequence is $372$.
# The answer is: 372.
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: For how many positive integers $m$ does the equation \[\vert \vert x-1 \vert -2 \vert=\frac{m}{100}\] have $4$ distinct solutions?
#
# Solution: Let's first understand the problem. The equation has the form $|\vert x-1 \vert -2|=\frac{m}{100}$. The number of solutions depends on the value of $m$. We want to find the number of values of $m$ for which the equation has $4$ distinct solutions.
#
# We can start by considering the inner absolute value expression $\vert x-1 \vert -2$. This expression can take on three different forms depending on the value of $x$:
#
# 1. If $x < 1$, we have $\vert x-1 \vert -2 = -(x-1) - 2 = -x + 1 - 2 = -x - 1$.
# 2. If $1 \leq x \leq 3$, we have $\vert x-1 \vert -2 = x - 1 - 2 = x - 3$.
# 3. If $x > 3$, we have $\vert x-1 \vert -2 = x - 1 - 2 = x - 3$.
#
# So, the equation $|\vert x-1 \vert -2|=\frac{m}{100}$ can be rewritten as:
#
# 1. If $x < 1$, we have $\vert -x - 1 \vert = \frac{m}{100}$, or $\vert x + 1 \vert = \frac{m}{100}$.
# 2. If $1 \leq x \leq 3$, we have $\vert x - 3 \vert = \frac{m}{100}$.
# 3. If $x > 3$, we have $\vert x - 3 \vert = \frac{m}{100}$.
#
# Now, let's analyze the number of solutions for each case:
#
# 1. If $x < 1$, the equation $\vert x + 1 \vert = \frac{m}{100}$ has two solutions if $\frac{m}{100} > 1$, or $m > 100$.
# 2. If $1 \leq x \leq 3$, the equation $\vert x - 3 \vert = \frac{m}{100}$ has two solutions if $0 < \frac{m}{100} \leq 2$, or $0 < m \leq 200$.
# 3. If $x > 3$, the equation $\vert x - 3 \vert = \frac{m}{100}$ has two solutions if $\frac{m}{100} > 2$, or $m > 200$.
#
# So, the equation $|\vert x-1 \vert -2|=\frac{m}{100}$ has $4$ distinct solutions when $0 < m \leq 200$. Therefore, there are $200$ positive integer values of $m$ for which the equation has $4$ distinct solutions. The answer is: $200$
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: Suppose that we roll four 6-sided fair dice with faces numbered 1 to~6. Let $a/b$ be the probability that the highest roll is a 5, where $a$ and $b$ are relatively prime positive integers. Find $a + b$.
# The value of $a+b$ is $\boxed{41}$.
# The value of $a+b$ is 41.
# The answer is: $41$
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: The points $\left(x, y\right)$ satisfying $((\vert x + y \vert - 10)^2 + ( \vert x - y \vert - 10)^2)((\vert x \vert - 8)^2 + ( \vert y \vert - 8)^2) = 0$ enclose a convex polygon. What is the area of this convex polygon?
#
# Solution: Let $f(x, y) = ((\vert x + y \vert - 10)^2 + (\vert x - y \vert - 10)^2)((\vert x \vert - 8)^2 + (\vert y \vert - 8)^2)$. For $f(x, y) = 0$, either $(\vert x + y \vert - 10)^2 = 0$, $(\vert x - y \vert - 10)^2 = 0$, $(\vert x \vert - 8)^2 = 0$, or $(\vert y \vert - 8)^2 = 0$.
#
# If $(\vert x + y \vert - 10)^2 = 0$, then $\vert x + y \vert = 10$, so $x + y = \pm 10$.
# If $(\vert x - y \vert - 10)^2 = 0$, then $\vert x - y \vert = 10$, so $x - y = \pm 10$.
# If $(\vert x \vert - 8)^2 = 0$, then $\vert x \vert = 8$, so $x = \pm 8$.
# If $(\vert y \vert - 8)^2 = 0$, then $\vert y \vert = 8$, so $y = \pm 8$.
#
# The solutions to these equations are:
# $x + y = \pm 10$: The lines $x + y = 10$ and $x + y = -10$.
# $x - y = \pm 10$: The lines $x - y = 10$ and $x - y = -10$.
# $x = \pm 8$: The lines $x = 8$ and $x = -8$.
# $y = \pm 8$: The lines $y = 8$ and $y = -8$.
#
# The points where these lines intersect are the vertices of the polygon. The polygon is a square with side length 16 units. The area of this square is $16^2 = 256$ square units. The answer is: 256
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: Let $ABCD$ be a unit square. Let $P$ be the point on $AB$ such that $|AP| = 1/{20}$ and let $Q$ be the point on $AD$ such that $|AQ| = 1/{24}$. The lines $DP$ and $BQ$ divide the square into four regions. Find the ratio between the areas of the largest region and the smallest region.
#
# Solution: First, let's find the areas of the four regions.
# The area of the entire square is 1.
# The area of triangle $ABQ$ is $\frac{1}{2} \cdot \frac{1}{24} \cdot 1 = \frac{1}{48}$.
# The area of triangle $DPC$ is $\frac{1}{2} \cdot \frac{1}{20} \cdot 1 = \frac{1}{40}$.
# The area of the quadrilateral $BPDQ$ is the area of the square minus the sum of the areas of the two triangles, which is $1 - \left(\frac{1}{48} + \frac{1}{40}\right) = 1 - \frac{48 + 40}{48 \cdot 40} = 1 - \frac{88}{24 \cdot 40} = 1 - \frac{11}{240} = \frac{240 - 11}{240} = \frac{229}{240}$.
# The area of the smallest region (the triangle with vertices at $P$, $Q$, and the origin) is $\frac{1}{2} \cdot \frac{1}{20} \cdot \frac{1}{24} = \frac{1}{480}$.
# The ratio of the area of the largest region ($BPDQ$) to the smallest region ($PQT$) is $\frac{\frac{229}{240}}{\frac{1}{480}} = \frac{229 \cdot 480}{240} = 229 \cdot 2 = 458$.
#
# Therefore, the ratio of the areas of the largest region and the smallest region is 458.
# The answer is: $458$
# Role:
# You are an advanced AI system with exceptional mathematical reasoning and problem-solving capabilities, specifically designed to solve tricky math problems (whose answer is a non-negative integer) written in LaTeX format from the AI Mathematical Olympiad (AIMO) competition. Your task is to accurately analyze and solve intricate mathematical problems, demonstrating a deep understanding of mathematical concepts and a strong ability to apply logical reasoning strategies.
#
# Instruction:
# 1. Carefully read and comprehend the problem statement provided in the "Problem" section.
# 2. In the "Solution" section, provide a solution of the problem with detailed explanation of your logical reasoning process. Keep in mind that answer must be a non-negative integer number.
# 3. At the end, create a "Answer" section where you will state only the final numerical or algebraic answer, without any additional text or narrative.
#
# Problem: A function $f: \mathbb N \to \mathbb N$ satisfies the following two conditions for all positive integers $n$:$f(f(f(n)))=8n-7$ and $f(2n)=2f(n)+1$. Calculate $f(100)$.
# The answer is $\boxed{199}$.

# %%
res
# Out:
# [110, 2, 5, 0, 372, 200, 41, 256, 458, 199]

# %%
df2
# Out:
#        id                                            problem  answer
# 0  229ee8  Let $k, l > 0$ be parameters. The parabola $y ...      52
# 1  246d26  Each of the three-digits numbers $111$ to $999...     250
# 2  2fc4ad  Let the `sparkle' operation on positive intege...     702
# 3  430b63  What is the minimum value of $5x^2+5y^2-8xy$ w...     800
# 4  5277ed  There exists a unique increasing geometric seq...     211
# 5  739bc9  For how many positive integers $m$ does the eq...     199
# 6  82e2a0  Suppose that we roll four 6-sided fair dice wi...     185
# 7  8ee6f3  The points $\left(x, y\right)$ satisfying $((\...     320
# 8  bedda4  Let $ABCD$ be a unit square. Let $P$ be the po...     480
# 9  d7e9c9  A function $f: \mathbb N \to \mathbb N$ satisf...     199

# %% [markdown]
# accuracy = 10%
